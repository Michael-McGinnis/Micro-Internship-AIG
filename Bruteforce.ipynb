# %%
import zipfile

def extract_file(zfile, password):
    try:
        zfile.extractall(pwd = bytes(password, 'utf-8'))
        return password
    except:
        print('Wrong Password')
        return

def main():
    print("[+] Beginning bruteforce ")
    zfile = zipfile.ZipFile('enc.zip')
    pass_file = open('rockyou.txt')
    for line in pass_file.readlines():
        password = line.strip('\n')
        guess = extract_file(zfile, password)
        if guess:
            print('Password = ' + password)
            break
            
if __name__ == "__main__":
    main()
# Out:
# [+] Beginning bruteforce
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Wrong Password
# Password = SPONGEBOB
